# %%
pip install azure-storage-blob snowflake-connector-python
# Out:
# ...
#      |████████████████████████████████| 409kB 6.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 204kB 13.8MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install notebook
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.storage.blob import BlobServiceClient
import os

# Connect to Azure Blob Storage
blob_service_client = BlobServiceClient.from_connection_string("your_connection_string")
container_client = blob_service_client.get_container_client("your_container_name")

# List blobs and find the latest one
blobs = container_client.list_blobs()
latest_blob = max(blobs, key=lambda b: b.last_modified)

print(f"Latest blob: {latest_blob.name}, Last modified: {latest_blob.last_modified}")

# %%
import snowflake.connector

# Connect to Snowflake
conn = snowflake.connector.connect(
    user='your_username',
    password='your_password',
    account='your_account'
)

# Create a cursor object
cur = conn.cursor()

# Load data from Azure Blob Storage into Snowflake
cur.execute(f"""
    COPY INTO your_table
    FROM 'azure://your_container_name.blob.core.windows.net/{latest_blob.name}'
    CREDENTIALS=(AZURE_SAS_TOKEN='your_sas_token')
    FILE_FORMAT = (TYPE = 'CSV')
""")

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import snowflake.connector
#       3 # Connect to Snowflake
# ----> 4 conn = snowflake.connector.connect(
#       5     user='your_username',
#       6     password='your_password',
#       7     account='your_account'
#       8 )
#      10 # Create a cursor object
#      11 cur = conn.cursor()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:457, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     455     kwargs = _get_default_connection_params()
# ...
